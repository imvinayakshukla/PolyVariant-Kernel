# %%
import joblib
# Load gene data
X_train_genes, X_test_genes, y_train_genes_cat, y_test_genes_cat, \
y_train_genes_int, y_test_genes_int, gene_label_encoder = joblib.load('0.95processed_gene_data.pkl')

# Load image data
X_train_images, X_test_images, y_train_images, y_test_images, image_label_encoder = joblib.load('0.95processed_image_data.pkl')

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import (accuracy_score, classification_report, 
                             confusion_matrix, matthews_corrcoef, roc_auc_score)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ------------------------------------------
# Gene Data: SVM with RBF Kernel and Grid Search
# ------------------------------------------
param_grid_gene = {
    'C': [0.01, 0.1, 1, 10, 100],
    'gamma': [0.0001, 0.00001, 0.000001],
    'kernel': ['rbf']
}

svm_gene = SVC(probability=True)
grid_search_gene = GridSearchCV(svm_gene, param_grid_gene, cv=5, verbose=3)
grid_search_gene.fit(X_train_genes, y_train_genes_int)

# Evaluate Gene Model
pred_gene_probs = grid_search_gene.best_estimator_.predict_proba(X_test_genes)
pred_gene = np.argmax(pred_gene_probs, axis=1)
accuracy_gene = accuracy_score(y_test_genes_int, pred_gene)
mcc_gene = matthews_corrcoef(y_test_genes_int, pred_gene)
conf_matrix_gene = confusion_matrix(y_test_genes_int, pred_gene)
print(f"SVM Gene Accuracy: {accuracy_gene:.4f}")
print(f"SVM Gene MCC: {mcc_gene:.4f}")

# AUC for Gene Model
try:
    auc_gene = roc_auc_score(y_test_genes_int, pred_gene_probs, multi_class='ovr')
    print(f"SVM Gene AUC: {auc_gene:.4f}")
except ValueError as e:
    print(f"SVM Gene AUC Error: {e}")

# Classification Report for Gene Model
print("\nGene Model Classification Report:")
print(classification_report(y_test_genes_int, pred_gene, target_names=gene_label_encoder.classes_))

# Gene Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_gene, annot=True, fmt='d', cmap='Blues', 
            xticklabels=gene_label_encoder.classes_, yticklabels=gene_label_encoder.classes_)
plt.title("Confusion Matrix - Gene Model")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# ------------------------------------------
# Image Data: SVM with RBF Kernel and Grid Search
# ------------------------------------------
param_grid_image = {
    'C': [0.01, 0.1, 1, 10, 50],
    'gamma': [0.001, 0.0001, 0.00001],
    'kernel': ['rbf']
}

svm_image = SVC(probability=True)
grid_search_image = GridSearchCV(svm_image, param_grid_image, cv=5)
grid_search_image.fit(X_train_images, y_train_images)

# Evaluate Image Model
pred_image_probs = grid_search_image.best_estimator_.predict_proba(X_test_images)
pred_image = np.argmax(pred_image_probs, axis=1)
accuracy_image = accuracy_score(y_test_images, pred_image)
mcc_image = matthews_corrcoef(y_test_images, pred_image)
conf_matrix_image = confusion_matrix(y_test_images, pred_image)
print(f"\nSVM Image Accuracy: {accuracy_image:.4f}")
print(f"SVM Image MCC: {mcc_image:.4f}")

# AUC for Image Model
try:
    auc_image = roc_auc_score(y_test_images, pred_image_probs, multi_class='ovr')
    print(f"SVM Image AUC: {auc_image:.4f}")
except ValueError as e:
    print(f"SVM Image AUC Error: {e}")

# Classification Report for Image Model
print("\nImage Model Classification Report:")
print(classification_report(y_test_images, pred_image, target_names=gene_label_encoder.classes_))

# Image Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_image, annot=True, fmt='d', cmap='Oranges', 
            xticklabels=gene_label_encoder.classes_, yticklabels=gene_label_encoder.classes_)
plt.title("Confusion Matrix - Image Model")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# ------------------------------------------
# Fusion Model: Fusion of SVM Outputs
# ------------------------------------------
# Align predictions
min_samples = min(pred_gene_probs.shape[0], pred_image_probs.shape[0])
pred_gene_aligned = pred_gene_probs[:min_samples]
pred_image_aligned = pred_image_probs[:min_samples]
y_test_aligned = y_test_genes_int[:min_samples]

# Fusion with weighted average
alpha, beta = 0.88185, 0.11815
fused_predictions = alpha * pred_gene_aligned + beta * pred_image_aligned
final_predictions = np.argmax(fused_predictions, axis=1)

# Evaluate Fusion Model
accuracy_fusion = accuracy_score(y_test_aligned, final_predictions)
mcc_fusion = matthews_corrcoef(y_test_aligned, final_predictions)
conf_matrix_fusion = confusion_matrix(y_test_aligned, final_predictions)
print(f"\nFusion Model Accuracy: {accuracy_fusion:.4f}")
print(f"Fusion Model MCC: {mcc_fusion:.4f}")

# AUC for Fusion Model
try:
    auc_fusion = roc_auc_score(y_test_aligned, fused_predictions, multi_class='ovr')
    print(f"Fusion Model AUC: {auc_fusion:.4f}")
except ValueError as e:
    print(f"Fusion Model AUC Error: {e}")

# Classification Report for Fusion Model
print("\nFusion Model Classification Report:")
print(classification_report(y_test_aligned, final_predictions, target_names=gene_label_encoder.classes_))

# Fusion Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_fusion, annot=True, fmt='d', cmap='Greens', 
            xticklabels=gene_label_encoder.classes_, yticklabels=gene_label_encoder.classes_)
plt.title("Confusion Matrix - Fusion Model")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ..C=0.01, gamma=0.0001, kernel=rbf;, score=0.262 total time=  16.5s
# [CV 2/5] END ..C=0.01, gamma=0.0001, kernel=rbf;, score=0.262 total time=  16.3s
# [CV 3/5] END ..C=0.01, gamma=0.0001, kernel=rbf;, score=0.265 total time=  16.8s
# [CV 4/5] END ..C=0.01, gamma=0.0001, kernel=rbf;, score=0.263 total time=  16.6s
# [CV 5/5] END ..C=0.01, gamma=0.0001, kernel=rbf;, score=0.263 total time=  16.5s
# [CV 1/5] END ...C=0.01, gamma=1e-05, kernel=rbf;, score=0.262 total time=  17.0s
# [CV 2/5] END ...C=0.01, gamma=1e-05, kernel=rbf;, score=0.262 total time=  16.4s
# [CV 3/5] END ...C=0.01, gamma=1e-05, kernel=rbf;, score=0.265 total time=  16.2s
# [CV 4/5] END ...C=0.01, gamma=1e-05, kernel=rbf;, score=0.263 total time=  16.4s
# [CV 5/5] END ...C=0.01, gamma=1e-05, kernel=rbf;, score=0.263 total time=  16.7s
# [CV 1/5] END ...C=0.01, gamma=1e-06, kernel=rbf;, score=0.262 total time=  16.8s
# [CV 2/5] END ...C=0.01, gamma=1e-06, kernel=rbf;, score=0.262 total time=  16.6s
# [CV 3/5] END ...C=0.01, gamma=1e-06, kernel=rbf;, score=0.265 total time=  17.3s
# [CV 4/5] END ...C=0.01, gamma=1e-06, kernel=rbf;, score=0.263 total time=  16.6s
# [CV 5/5] END ...C=0.01, gamma=1e-06, kernel=rbf;, score=0.263 total time=  16.8s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.330 total time=  16.9s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.389 total time=  16.9s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.383 total time=  17.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.384 total time=  17.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0

# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.806 total time=  15.3s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.868 total time=  15.7s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.992 total time=  15.6s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.980 total time=  15.8s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.963 total time=  15.7s
# [CV 1/5] END ....C=100, gamma=1e-05, kernel=rbf;, score=0.980 total time=   5.8s
# [CV 2/5] END ....C=100, gamma=1e-05, kernel=rbf;, score=0.977 total time=   5.6s
# [CV 3/5] END ....C=100, gamma=1e-05, kernel=rbf;, score=0.972 total time=   6.3s
# [CV 4/5] END ....C=100, gamma=1e-05, kernel=rbf;, score=0.983 total time=   6.4s
# [CV 5/5] END ....C=100, gamma=1e-05, kernel=rbf;, score=0.986 total time=   6.1s
# [CV 1/5] END ....C=100, gamma=1e-06, kernel=rbf;, score=0.975 total time=   4.1s
# [CV 2/5] END ....C=100, gamma=1e-06, kernel=rbf;, score=0.975 total time=   4.1s
# [CV 3/5] END ....C=100, gamma=1e-06, kernel=rbf;, score=0.969 total time=   4.4s
# [CV 4/5] END ....C=100, gamma=1e-06, kernel=rbf;, score=0.989 total time=   4.4s
# [CV 5/5] END ....C=100, gamma=1e-06, kernel=rbf;, score=0.986 total time=   4.4s
# SVM Gene Accuracy: 0.8846
# SVM Gene MCC: 0.8200
# SVM Gene AUC: 0.9759
#
# Gene Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       1.00      1.00      1.00        34
#    BRCA_Her2       1.00      0.79      0.88        19
#    BRCA_LumA       0.85      0.97      0.91       109
#    BRCA_LumB       0.85      0.63      0.72        46
#
#     accuracy                           0.88       208
#    macro avg       0.93      0.85      0.88       208
# weighted avg       0.89      0.88      0.88       208
# SVM Image Accuracy: 0.5866
# SVM Image MCC: 0.3451
# SVM Image AUC: 0.7605
#
# Image Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.59      0.59      0.59        34
#    BRCA_Her2       0.50      0.06      0.10        18
#    BRCA_LumA       0.68      0.83      0.75        88
#    BRCA_LumB       0.31      0.28      0.29        39
#
#     accuracy                           0.59       179
#    macro avg       0.52      0.44      0.43       179
# weighted avg       0.56      0.59      0.55       179
# Fusion Model Accuracy: 0.8659
# Fusion Model MCC: 0.7911
# Fusion Model AUC: 0.9655
#
# Fusion Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       1.00      1.00      1.00        28
#    BRCA_Her2       1.00      0.72      0.84        18
#    BRCA_LumA       0.83      0.98      0.90        94
#    BRCA_LumB       0.81      0.56      0.67        39
#
#     accuracy                           0.87       179
#    macro avg       0.91      0.82      0.85       179
# weighted avg       0.87      0.87      0.86       179

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import (
    accuracy_score, classification_report, confusion_matrix, 
    matthews_corrcoef, roc_auc_score
)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ===========================
# SVM for Gene Data
# ===========================
param_grid_gene = {
    'C': [0.01, 0.1, 1, 10, 100],
    'gamma': [0.0001, 0.00001, 0.000001],
    'kernel': ['poly'],
    'degree': [2, 3, 4]
}

svm_gene = SVC(probability=True)
grid_search_gene = GridSearchCV(svm_gene, param_grid_gene, cv=5, verbose=3)
grid_search_gene.fit(X_train_genes, y_train_genes_int)

# Predictions and Probabilities
pred_gene_probs = grid_search_gene.best_estimator_.predict_proba(X_test_genes)
pred_gene = np.argmax(pred_gene_probs, axis=1)

# Accuracy
accuracy_gene = accuracy_score(y_test_genes_int, pred_gene)
print(f"Gene SVM Accuracy: {accuracy_gene:.4f}")

# Classification Report
print("\nGene Model Classification Report:")
print(classification_report(y_test_genes_int, pred_gene, target_names=gene_label_encoder.classes_))

# Confusion Matrix
conf_matrix_gene = confusion_matrix(y_test_genes_int, pred_gene)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_gene, annot=True, fmt='d', cmap='Blues', 
            xticklabels=gene_label_encoder.classes_, 
            yticklabels=gene_label_encoder.classes_)
plt.title('Gene Model - Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Matthews Correlation Coefficient (MCC)
mcc_gene = matthews_corrcoef(y_test_genes_int, pred_gene)
print(f"Gene Model MCC: {mcc_gene:.4f}")

# AUC Score
try:
    auc_gene = roc_auc_score(y_test_genes_int, pred_gene_probs, multi_class='ovr', average='weighted')
    print(f"Gene Model AUC: {auc_gene:.4f}")
except ValueError as e:
    print(f"Gene Model AUC calculation error: {e}")

# ===========================
# SVM for Image Data
# ===========================
param_grid_image = {
    'C': [0.1, 1, 10],
    'gamma': [0.001, 0.0001, 0.00001],
    'kernel': ['poly'],
    'degree': [2, 3, 4]
}

svm_image = SVC(probability=True)
grid_search_image = GridSearchCV(svm_image, param_grid_image, cv=5)
grid_search_image.fit(X_train_images, y_train_images)

# Predictions and Probabilities
pred_image_probs = grid_search_image.best_estimator_.predict_proba(X_test_images)
pred_image = np.argmax(pred_image_probs, axis=1)

# Accuracy
accuracy_image = accuracy_score(y_test_images, pred_image)
print(f"Image SVM Accuracy: {accuracy_image:.4f}")

# Classification Report
print("\nImage Model Classification Report:")
print(classification_report(y_test_images, pred_image, target_names=gene_label_encoder.classes_))

# Confusion Matrix
conf_matrix_image = confusion_matrix(y_test_images, pred_image)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_image, annot=True, fmt='d', cmap='Blues', 
            xticklabels=gene_label_encoder.classes_, 
            yticklabels=gene_label_encoder.classes_)
plt.title('Image Model - Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Matthews Correlation Coefficient (MCC)
mcc_image = matthews_corrcoef(y_test_images, pred_image)
print(f"Image Model MCC: {mcc_image:.4f}")

# AUC Score
try:
    auc_image = roc_auc_score(y_test_images, pred_image_probs, multi_class='ovr', average='weighted')
    print(f"Image Model AUC: {auc_image:.4f}")
except ValueError as e:
    print(f"Image Model AUC calculation error: {e}")

# ===========================
# Fusion of Gene and Image SVM Outputs
# ===========================
min_samples = min(pred_gene_probs.shape[0], pred_image_probs.shape[0])
pred_gene_aligned = pred_gene_probs[:min_samples]
pred_image_aligned = pred_image_probs[:min_samples]
y_test_aligned = y_test_genes_int[:min_samples]

# Weighted Fusion
alpha, beta = 0.88185, 0.11815
fused_predictions = alpha * pred_gene_aligned + beta * pred_image_aligned
final_predictions = np.argmax(fused_predictions, axis=1)

# Accuracy
accuracy_fusion = accuracy_score(y_test_aligned, final_predictions)
print(f"Fusion Model Accuracy: {accuracy_fusion:.4f}")

# Classification Report
print("\nFusion Model Classification Report:")
print(classification_report(y_test_aligned, final_predictions, 
                            target_names=gene_label_encoder.classes_))

# Confusion Matrix
conf_matrix_fusion = confusion_matrix(y_test_aligned, final_predictions)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_fusion, annot=True, fmt='d', cmap='Blues', 
            xticklabels=gene_label_encoder.classes_, 
            yticklabels=gene_label_encoder.classes_)
plt.title('Fusion Model - Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Matthews Correlation Coefficient (MCC)
mcc_fusion = matthews_corrcoef(y_test_aligned, final_predictions)
print(f"Fusion Model MCC: {mcc_fusion:.4f}")

# AUC Score
try:
    auc_fusion = roc_auc_score(y_test_aligned, fused_predictions, multi_class='ovr', average='weighted')
    print(f"Fusion Model AUC: {auc_fusion:.4f}")
except ValueError as e:
    print(f"Fusion Model AUC calculation error: {e}")
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV 1/5] END C=0.01, degree=2, gamma=0.0001, kernel=poly;, score=0.814 total time=  11.1s
# [CV 2/5] END C=0.01, degree=2, gamma=0.0001, kernel=poly;, score=0.873 total time=  11.1s
# [CV 3/5] END C=0.01, degree=2, gamma=0.0001, kernel=poly;, score=0.851 total time=  11.3s
# [CV 4/5] END C=0.01, degree=2, gamma=0.0001, kernel=poly;, score=0.782 total time=   7.3s
# [CV 5/5] END C=0.01, degree=2, gamma=0.0001, kernel=poly;, score=0.825 total time=   5.9s
# [CV 1/5] END C=0.01, degree=2, gamma=1e-05, kernel=poly;, score=0.262 total time=   7.1s
# [CV 2/5] END C=0.01, degree=2, gamma=1e-05, kernel=poly;, score=0.262 total time=   7.4s
# [CV 3/5] END C=0.01, degree=2, gamma=1e-05, kernel=poly;, score=0.265 total time=   7.5s
# [CV 4/5] END C=0.01, degree=2, gamma=1e-05, kernel=poly;, score=0.263 total time=   7.5s
# [CV 5/5] END C=0.01, degree=2, gamma=1e-05, kernel=poly;, score=0.263 total time=   7.3s
# [CV 1/5] END C=0.01, degree=2, gamma=1e-06, kernel=poly;, score=0.262 total time=   7.1s
# [CV 2/5] END C=0.01, degree=2, gamma=1e-06, kernel=poly;, score=0.262 total time=   6.3s
# [CV 3/5] END C=0.01, degree=2, gamma=1e-06, kernel=poly;, score=0.265 total time=   4.9s
# [CV 4/5] END C=0.01, degree=2, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.1s
# [CV 5/5] END C=0.01, degree=2, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.0s
# [CV 1/5] END C=0.01, degree=3, gamma=0.0001, kernel=poly;, score=0.932 total time=   3.8s
# [CV 2/5] END C=0.01, degree=3, gamma=0.0001, kernel=poly;, score=0.975 total time=   3.6s
# [CV 3/5] END C=0.01, degree=3, gamma=0.0001, kernel=poly;, score=0.941 total time=   3.6s
# [CV 4/5] END C=0.01, degree=3, gamma=0.0001, kernel=poly;, score=0.910 total time=   3.7s
# [CV 5/5] END C=0.01, degree=3, gamma=0.0001, kernel=poly;, score=0.927 total time=   3.9s
# [CV 1/5] END C=0.01, degree=3, gamma=1e-05, kernel=poly;, score=0.262 total time=   5.3s
# [CV 2/5] END C=0.01, degree=3, gamma=1e-05, kernel=poly;, score=0.262 total time=   5.4s
# [CV 3/5] END C=0.01, degree=3, gamma=1e-05, kernel=poly;, score=0.265 total time=   5.3s
# [CV 4/5] END C=0.01, degree=3, gamma=1e-05, kernel=poly;, score=0.263 total time=   5.5s
# [CV 5/5] END C=0.01, degree=3, gamma=1e-05, kernel=poly;, score=0.263 total time=   5.5s
# [CV 1/5] END C=0.01, degree=3, gamma=1e-06, kernel=poly;, score=0.262 total time=   5.1s
# [CV 2/5] END C=0.01, degree=3, gamma=1e-06, kernel=poly;, score=0.262 total time=   5.2s
# [CV 3/5] END C=0.01, degree=3, gamma=1e-06, kernel=poly;, score=0.265 total time=   5.0s
# [CV 4/5] END C=0.01, degree=3, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.3s
# [CV 5/5] END C=0.01, degree=3, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.2s
# [CV 1/5] END C=0.01, degree=4, gamma=0.0001, kernel=poly;, score=0.946 total time=   4.4s
# [CV 2/5] END C=0.01, degree=4, gamma=0.0001, kernel=poly;, score=0.924 total time=   4.4s
# [CV 3/5] END C=0.01, degree=4, gamma=0.0001, kernel=poly;, score=0.870 total time=   4.4s
# [CV 4/5] END C=0.01, degree=4, gamma=0.0001, kernel=poly;, score=0.836 total time=   4.2s
# [CV 5/5] END C=0.01, degree=4, gamma=0.0001, kernel=poly;, score=0.893 total time=   4.3s
# [CV 1/5] END C=0.01, degree=4, gamma=1e-05, kernel=poly;, score=0.262 total time=   5.3s
# [CV 2/5] END C=0.01, degree=4, gamma=1e-05, kernel=poly;, score=0.262 total time=   5.4s
# [CV 3/5] END C=0.01, degree=4, gamma=1e-05, kernel=poly;, score=0.265 total time=   5.6s
# [CV 4/5] END C=0.01, degree=4, gamma=1e-05, kernel=poly;, score=0.263 total time=   5.5s
# [CV 5/5] END C=0.01, degree=4, gamma=1e-05, kernel=poly;, score=0.263 total time=   5.5s
# [CV 1/5] END C=0.01, degree=4, gamma=1e-06, kernel=poly;, score=0.262 total time=   5.6s
# [CV 2/5] END C=0.01, degree=4, gamma=1e-06, kernel=poly;, score=0.262 total time=   5.5s
# [CV 3/5] END C=0.01, degree=4, gamma=1e-06, kernel=poly;, score=0.265 total time=   5.4s
# [CV 4/5] END C=0.01, degree=4, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.6s
# [CV 5/5] END C=0.01, degree=4, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.4s
# [CV 1/5] END C=0.1, degree=2, gamma=0.0001, kernel=poly;, score=0.961 total time=   3.4s
# [CV 2/5] END C=0.1, degree=2, gamma=0.0001, kernel=poly;, score=0.952 total time=   3.4s
# [CV 3/5] END C=0.1, degree=2, gamma=0.0001, kernel=poly;, score=0.992 total time=   3.6s
# [CV 4/5] END C=0.1, degree=2, gamma=0.0001, kernel=poly;, score=0.977 total time=   3.5s
# [CV 5/5] END C=0.1, degree=2, gamma=0.0001, kernel=poly;, score=0.980 total time=   3.5s
# [CV 1/5] END C=0.1, degree=2, gamma=1e-05, kernel=poly;, score=0.515 total time=   5.3s
# [CV 2/5] END C=0.1, degree=2, gamma=1e-05, kernel=poly;, score=0.515 total time=   5.3s
# [CV 3/5] END C=0.1, degree=2, gamma=1e-05, kernel=poly;, score=0.521 total time=   5.3s
# [CV 4/5] END C=0.1, degree=2, gamma=1e-05, kernel=poly;, score=0.525 total time=   5.3s
# [CV 5/5] END C=0.1, degree=2, gamma=1e-05, kernel=poly;, score=0.497 total time=   5.1s
# [CV 1/5] END C=0.1, degree=2, gamma=1e-06, kernel=poly;, score=0.262 total time=   4.8s
# [CV 2/5] END C=0.1, degree=2, gamma=1e-06, kernel=poly;, score=0.262 total time=   5.1s
# [CV 3/5] END C=0.1, degree=2, gamma=1e-06, kernel=poly;, score=0.265 total time=   5.1s
# [CV 4/5] END C=0.1, degree=2, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.4s
# [CV 5/5] END C=0.1, degree=2, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.0001, kernel=poly;, score=0.969 total time=   3.5s
# [CV 2/5] END C=0.1, degree=3, gamma=0.0001, kernel=poly;, score=0.975 total time=   3.3s
# [CV 3/5] END C=0.1, degree=3, gamma=0.0001, kernel=poly;, score=0.986 total time=   3.5s
# [CV 4/5] END C=0.1, degree=3, gamma=0.0001, kernel=poly;, score=0.986 total time=   3.4s
# [CV 5/5] END C=0.1, degree=3, gamma=0.0001, kernel=poly;, score=0.980 total time=   3.7s
# [CV 1/5] END C=0.1, degree=3, gamma=1e-05, kernel=poly;, score=0.273 total time=   5.3s
# [CV 2/5] END C=0.1, degree=3, gamma=1e-05, kernel=poly;, score=0.270 total time=   5.3s
# [CV 3/5] END C=0.1, degree=3, gamma=1e-05, kernel=poly;, score=0.273 total time=   5.4s
# [CV 4/5] END C=0.1, degree=3, gamma=1e-05, kernel=poly;, score=0.268 total time=   5.6s
# [CV 5/5] END C=0.1, degree=3, gamma=1e-05, kernel=poly;, score=0.280 total time=   5.6s
# [CV 1/5] END C=0.1, degree=3, gamma=1e-06, kernel=poly;, score=0.262 total time=   5.3s
# [CV 2/5] END C=0.1, degree=3, gamma=1e-06, kernel=poly;, score=0.262 total time=   5.4s
# [CV 3/5] END C=0.1, degree=3, gamma=1e-06, kernel=poly;, score=0.265 total time=   5.2s
# [CV 4/5] END C=0.1, degree=3, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.2s
# [CV 5/5] END C=0.1, degree=3, gamma=1e-06, kernel=poly;, score=0.263 total time=   5.2s
# [CV 1/5] END C=0.1, degree=4, gamma=0.0001, kernel=poly;, score=0.955 total time=   4.7s
# [CV 2/5] END C=0.1, degree=4, gamma=0.0001, kernel=poly;, score=0.941 total time=   4.7s
# [CV 3/5] END C=0.1, degree=4, gamma=0.0001, kernel=poly;, score=0.932 total time=   4.8s
# [CV 4/5] END C=0.1, degree=4, gamma=0.0001, kernel=poly;, score=0.907 total time=   4.6s
# [CV 5/5] END C=0.1, degree=4, gamma=0.0001, kernel=poly;, score=0.955 total time=   4.6s
# [CV 1/5] END C=0.1, degree=4, gamma=1e-05, kernel=poly;, score=0.273 total time=   5.6s
# [CV 2/5] END C=0.1, degree=4, gamma=1e-05, kernel=poly;, score=0.279 total time=   5.2s
# [CV 3/5] END C=0.1, degree=4, gamma=1e-05, kernel=poly;, score=0.273 total time=   5.5s
# [CV 4/5] END C=0.1, degree=4, gamma=1e-05, kernel=poly;, score=0.268 total time=   5.7s
# [CV 2/5] END C=100, degree=3, gamma=1e-06, kernel=poly;, score=0.270 total time=   5.2s
# [CV 3/5] END C=100, degree=3, gamma=1e-06, kernel=poly;, score=0.273 total time=   5.9s
# [CV 4/5] END C=100, degree=3, gamma=1e-06, kernel=poly;, score=0.268 total time=   6.5s
# [CV 5/5] END C=100, degree=3, gamma=1e-06, kernel=poly;, score=0.280 total time=   5.4s
# [CV 1/5] END C=100, degree=4, gamma=0.0001, kernel=poly;, score=0.958 total time=   4.4s
# [CV 2/5] END C=100, degree=4, gamma=0.0001, kernel=poly;, score=0.941 total time=   4.5s
# [CV 3/5] END C=100, degree=4, gamma=0.0001, kernel=poly;, score=0.938 total time=   5.3s
# [CV 4/5] END C=100, degree=4, gamma=0.0001, kernel=poly;, score=0.910 total time=   5.4s
# [CV 5/5] END C=100, degree=4, gamma=0.0001, kernel=poly;, score=0.958 total time=   5.4s
# [CV 1/5] END C=100, degree=4, gamma=1e-05, kernel=poly;, score=0.946 total time=   4.9s
# [CV 2/5] END C=100, degree=4, gamma=1e-05, kernel=poly;, score=0.924 total time=   5.2s
# [CV 3/5] END C=100, degree=4, gamma=1e-05, kernel=poly;, score=0.870 total time=   5.2s
# [CV 4/5] END C=100, degree=4, gamma=1e-05, kernel=poly;, score=0.836 total time=   5.3s
# [CV 5/5] END C=100, degree=4, gamma=1e-05, kernel=poly;, score=0.893 total time=   5.3s
# [CV 1/5] END C=100, degree=4, gamma=1e-06, kernel=poly;, score=0.262 total time=   6.5s
# [CV 2/5] END C=100, degree=4, gamma=1e-06, kernel=poly;, score=0.262 total time=   6.6s
# [CV 3/5] END C=100, degree=4, gamma=1e-06, kernel=poly;, score=0.265 total time=   6.7s
# [CV 4/5] END C=100, degree=4, gamma=1e-06, kernel=poly;, score=0.263 total time=   6.6s
# [CV 5/5] END C=100, degree=4, gamma=1e-06, kernel=poly;, score=0.263 total time=   6.3s
# Gene SVM Accuracy: 0.8365
#
# Gene Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.97      0.97      0.97        34
#    BRCA_Her2       1.00      0.47      0.64        19
#    BRCA_LumA       0.81      0.95      0.87       109
#    BRCA_LumB       0.78      0.61      0.68        46
#
#     accuracy                           0.84       208
#    macro avg       0.89      0.75      0.79       208
# weighted avg       0.84      0.84      0.83       208
# Gene Model MCC: 0.7406
# Gene Model AUC: 0.9578
# Image SVM Accuracy: 0.5642
#
# Image Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.60      0.35      0.44        34
#    BRCA_Her2       0.00      0.00      0.00        18
#    BRCA_LumA       0.58      0.91      0.71        88
#    BRCA_LumB       0.43      0.23      0.30        39
#
#     accuracy                           0.56       179
#    macro avg       0.40      0.37      0.36       179
# weighted avg       0.49      0.56      0.50       179
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Image Model MCC: 0.2757
# Image Model AUC: 0.7140
# Fusion Model Accuracy: 0.8212
#
# Fusion Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.97      1.00      0.98        28
#    BRCA_Her2       1.00      0.44      0.62        18
#    BRCA_LumA       0.79      0.95      0.86        94
#    BRCA_LumB       0.76      0.56      0.65        39
#
#     accuracy                           0.82       179
#    macro avg       0.88      0.74      0.78       179
# weighted avg       0.83      0.82      0.81       179
# Fusion Model MCC: 0.7164
# Fusion Model AUC: 0.9474

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, matthews_corrcoef, roc_auc_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Custom utility kernel function
def utilitykernel(x1, x2, a, p=1):
    x1 = x1.flatten()
    x2 = x2.flatten()
    dot_product = np.dot(x1, x2)
    result = np.log(np.power(np.cosh(a * dot_product), p))
    max_value = 700
    return np.clip(result, -max_value, max_value)

# Custom Gram matrix computation
def gaussianKernelGramMatrix(X1, X2, a, K_function=utilitykernel):
    gram_matrix = np.zeros((X1.shape[0], X2.shape[0]))
    for i, x1 in enumerate(X1):
        for j, x2 in enumerate(X2):
            gram_matrix[i, j] = K_function(x1, x2, a)
    return gram_matrix

# Parameters for the custom kernel
a = 0.001
p = 2

# Generate Gram matrices for gene data
X_train_gene_gram = gaussianKernelGramMatrix(X_train_genes, X_train_genes, a)
X_test_gene_gram = gaussianKernelGramMatrix(X_test_genes, X_train_genes, a)

# SVM with custom kernel and Grid Search for gene data
param_grid_gene = {
    'C': [0.001, 0.01, 0.1, 1, 10, 50],
    'kernel': ['precomputed'],
}

svm_gene = SVC(probability=True, class_weight='balanced', random_state=42)
grid_search_gene = GridSearchCV(svm_gene, param_grid_gene, cv=5, verbose=3)
grid_search_gene.fit(X_train_gene_gram, y_train_genes_int)

# Evaluate SVM on gene data
y_pred_gene_probs = grid_search_gene.best_estimator_.predict_proba(X_test_gene_gram)
y_pred_gene = np.argmax(y_pred_gene_probs, axis=1)
gene_accuracy = accuracy_score(y_test_genes_int, y_pred_gene)
print(f"SVM Gene Accuracy with Custom Kernel: {gene_accuracy:.4f}")

# Confusion matrix for gene data
cm_gene = confusion_matrix(y_test_genes_int, y_pred_gene)
sns.heatmap(cm_gene, annot=True, fmt='d', cmap='Blues', xticklabels=gene_label_encoder.classes_, yticklabels=gene_label_encoder.classes_)
plt.title('Confusion Matrix - Gene Data')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Classification report for gene data
print("\nClassification Report - Gene Data:")
print(classification_report(y_test_genes_int, y_pred_gene, target_names=gene_label_encoder.classes_))

# Matthews Correlation Coefficient (MCC) for gene data
mcc_gene = matthews_corrcoef(y_test_genes_int, y_pred_gene)
print(f"MCC - Gene Data: {mcc_gene:.4f}")

# AUC for gene data (multi-class)
auc_gene = roc_auc_score(y_test_genes_int, y_pred_gene_probs, multi_class='ovr')
print(f"AUC - Gene Data: {auc_gene:.4f}")


# Generate Gram matrices for image data
X_train_image_gram = gaussianKernelGramMatrix(X_train_images, X_train_images, a)
X_test_image_gram = gaussianKernelGramMatrix(X_test_images, X_train_images, a)

# SVM with custom kernel and Grid Search for image data
param_grid_image = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'kernel': ['precomputed'],
}

svm_image = SVC(probability=True, class_weight='balanced', random_state=42)
grid_search_image = GridSearchCV(svm_image, param_grid_image, cv=5, verbose=3)
grid_search_image.fit(X_train_image_gram, y_train_images)

# Evaluate SVM on image data
y_pred_image_probs = grid_search_image.best_estimator_.predict_proba(X_test_image_gram)
y_pred_image = np.argmax(y_pred_image_probs, axis=1)
image_accuracy = accuracy_score(y_test_images, y_pred_image)
print(f"SVM Image Accuracy with Custom Kernel: {image_accuracy:.4f}")

# Confusion matrix for image data
cm_image = confusion_matrix(y_test_images, y_pred_image)
sns.heatmap(cm_image, annot=True, fmt='d', cmap='Blues', xticklabels=image_label_encoder.classes_, yticklabels=image_label_encoder.classes_)
plt.title('Confusion Matrix - Image Data')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Classification report for image data
print("\nClassification Report - Image Data:")
print(classification_report(y_test_images, y_pred_image, target_names=image_label_encoder.classes_))

# Matthews Correlation Coefficient (MCC) for image data
mcc_image = matthews_corrcoef(y_test_images, y_pred_image)
print(f"MCC - Image Data: {mcc_image:.4f}")

# AUC for image data (multi-class)
auc_image = roc_auc_score(y_test_images, y_pred_image_probs, multi_class='ovr')
print(f"AUC - Image Data: {auc_image:.4f}")


# Align prediction arrays for fusion
min_samples = min(y_pred_gene_probs.shape[0], y_pred_image_probs.shape[0])
pred_gene_aligned = y_pred_gene_probs[:min_samples]
pred_image_aligned = y_pred_image_probs[:min_samples]
y_test_aligned = y_test_genes_int[:min_samples]

# Fusion of SVM outputs
alpha, beta = 0.88185, 0.11815
fused_predictions = alpha * pred_gene_aligned + beta * pred_image_aligned
final_predictions = np.argmax(fused_predictions, axis=1)

# Evaluate fusion model
fusion_accuracy = accuracy_score(y_test_aligned, final_predictions)
print(f"Fusion Model Accuracy: {fusion_accuracy:.4f}")

# Confusion matrix for fusion model
cm_fusion = confusion_matrix(y_test_aligned, final_predictions)
sns.heatmap(cm_fusion, annot=True, fmt='d', cmap='Blues', xticklabels=gene_label_encoder.classes_, yticklabels=gene_label_encoder.classes_)
plt.title('Confusion Matrix - Fusion Model')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Classification report for fusion model
print("\nClassification Report - Fusion Model:")
print(classification_report(y_test_aligned, final_predictions, target_names=gene_label_encoder.classes_))

# Matthews Correlation Coefficient (MCC) for fusion model
mcc_fusion = matthews_corrcoef(y_test_aligned, final_predictions)
print(f"MCC - Fusion Model: {mcc_fusion:.4f}")

# AUC for fusion model (multi-class)
auc_fusion = roc_auc_score(y_test_aligned, fused_predictions, multi_class='ovr')
print(f"AUC - Fusion Model: {auc_fusion:.4f}")
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_19296\2391523710.py:13: RuntimeWarning: overflow encountered in cosh
#   result = np.log(np.power(np.cosh(a * dot_product), p))
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END .......C=0.001, kernel=precomputed;, score=0.662 total time=   0.4s
# [CV 2/5] END .......C=0.001, kernel=precomputed;, score=0.800 total time=   0.3s
# [CV 3/5] END .......C=0.001, kernel=precomputed;, score=0.794 total time=   0.5s
# [CV 4/5] END .......C=0.001, kernel=precomputed;, score=0.757 total time=   0.4s
# [CV 5/5] END .......C=0.001, kernel=precomputed;, score=0.782 total time=   0.4s
# [CV 1/5] END ........C=0.01, kernel=precomputed;, score=0.862 total time=   0.3s
# [CV 2/5] END ........C=0.01, kernel=precomputed;, score=0.873 total time=   0.3s
# [CV 3/5] END ........C=0.01, kernel=precomputed;, score=0.896 total time=   0.3s
# [CV 4/5] END ........C=0.01, kernel=precomputed;, score=0.901 total time=   0.3s
# [CV 5/5] END ........C=0.01, kernel=precomputed;, score=0.864 total time=   0.3s
# [CV 1/5] END .........C=0.1, kernel=precomputed;, score=0.808 total time=   0.4s
# [CV 2/5] END .........C=0.1, kernel=precomputed;, score=0.848 total time=   0.4s
# [CV 3/5] END .........C=0.1, kernel=precomputed;, score=0.862 total time=   0.5s
# [CV 4/5] END .........C=0.1, kernel=precomputed;, score=0.870 total time=   0.5s
# [CV 5/5] END .........C=0.1, kernel=precomputed;, score=0.859 total time=   0.5s
# [CV 1/5] END ...........C=1, kernel=precomputed;, score=0.746 total time=   0.5s
# [CV 2/5] END ...........C=1, kernel=precomputed;, score=0.794 total time=   0.5s
# [CV 3/5] END ...........C=1, kernel=precomputed;, score=0.825 total time=   0.5s
# [CV 4/5] END ...........C=1, kernel=precomputed;, score=0.853 total time=   0.5s
# [CV 5/5] END ...........C=1, kernel=precomputed;, score=0.836 total time=   0.6s
# [CV 1/5] END ..........C=10, kernel=precomputed;, score=0.727 total time=   0.6s
# [CV 2/5] END ..........C=10, kernel=precomputed;, score=0.783 total time=   0.3s
# [CV 3/5] END ..........C=10, kernel=precomputed;, score=0.808 total time=   0.4s
# [CV 4/5] END ..........C=10, kernel=precomputed;, score=0.833 total time=   0.6s
# [CV 5/5] END ..........C=10, kernel=precomputed;, score=0.828 total time=   0.6s
# [CV 1/5] END ..........C=50, kernel=precomputed;, score=0.724 total time=   0.6s
# [CV 2/5] END ..........C=50, kernel=precomputed;, score=0.780 total time=   0.6s
# [CV 3/5] END ..........C=50, kernel=precomputed;, score=0.820 total time=   0.6s
# [CV 4/5] END ..........C=50, kernel=precomputed;, score=0.831 total time=   0.7s
# [CV 5/5] END ..........C=50, kernel=precomputed;, score=0.822 total time=   0.6s
# SVM Gene Accuracy with Custom Kernel: 0.7019
# Classification Report - Gene Data:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.86      0.88      0.87        34
#    BRCA_Her2       0.89      0.42      0.57        19
#    BRCA_LumA       0.71      0.80      0.75       109
#    BRCA_LumB       0.51      0.46      0.48        46
#
#     accuracy                           0.70       208
#    macro avg       0.74      0.64      0.67       208
# weighted avg       0.71      0.70      0.69       208
#
# MCC - Gene Data: 0.5191
# AUC - Gene Data: 0.8684
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END .......C=0.001, kernel=precomputed;, score=0.084 total time=   0.0s
# [CV 2/5] END .......C=0.001, kernel=precomputed;, score=0.252 total time=   0.0s
# [CV 3/5] END .......C=0.001, kernel=precomputed;, score=0.252 total time=   0.0s
# [CV 4/5] END .......C=0.001, kernel=precomputed;, score=0.252 total time=   0.0s
# [CV 5/5] END .......C=0.001, kernel=precomputed;, score=0.472 total time=   0.0s
# [CV 1/5] END ........C=0.01, kernel=precomputed;, score=0.084 total time=   0.0s
# [CV 2/5] END ........C=0.01, kernel=precomputed;, score=0.252 total time=   0.1s
# [CV 3/5] END ........C=0.01, kernel=precomputed;, score=0.252 total time=   0.1s
# [CV 4/5] END ........C=0.01, kernel=precomputed;, score=0.252 total time=   0.1s
# [CV 5/5] END ........C=0.01, kernel=precomputed;, score=0.472 total time=   0.0s
# [CV 1/5] END .........C=0.1, kernel=precomputed;, score=0.091 total time=   0.0s
# [CV 2/5] END .........C=0.1, kernel=precomputed;, score=0.196 total time=   0.0s
# [CV 3/5] END .........C=0.1, kernel=precomputed;, score=0.210 total time=   0.0s
# [CV 4/5] END .........C=0.1, kernel=precomputed;, score=0.189 total time=   0.0s
# [CV 5/5] END .........C=0.1, kernel=precomputed;, score=0.472 total time=   0.0s
# [CV 1/5] END ...........C=1, kernel=precomputed;, score=0.469 total time=   0.0s
# [CV 2/5] END ...........C=1, kernel=precomputed;, score=0.441 total time=   0.0s
# [CV 3/5] END ...........C=1, kernel=precomputed;, score=0.490 total time=   0.0s
# [CV 4/5] END ...........C=1, kernel=precomputed;, score=0.503 total time=   0.0s
# [CV 5/5] END ...........C=1, kernel=precomputed;, score=0.444 total time=   0.0s
# [CV 1/5] END ..........C=10, kernel=precomputed;, score=0.427 total time=   0.0s
# [CV 2/5] END ..........C=10, kernel=precomputed;, score=0.497 total time=   0.0s
# [CV 3/5] END ..........C=10, kernel=precomputed;, score=0.455 total time=   0.0s
# [CV 4/5] END ..........C=10, kernel=precomputed;, score=0.483 total time=   0.0s
# [CV 5/5] END ..........C=10, kernel=precomputed;, score=0.472 total time=   0.0s
# [CV 1/5] END .........C=100, kernel=precomputed;, score=0.483 total time=   0.2s
# [CV 2/5] END .........C=100, kernel=precomputed;, score=0.538 total time=   0.2s
# [CV 3/5] END .........C=100, kernel=precomputed;, score=0.399 total time=   0.2s
# [CV 4/5] END .........C=100, kernel=precomputed;, score=0.469 total time=   0.2s
# [CV 5/5] END .........C=100, kernel=precomputed;, score=0.465 total time=   0.2s
# SVM Image Accuracy with Custom Kernel: 0.5419
# Classification Report - Image Data:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.55      0.32      0.41        34
#    BRCA_Her2       0.00      0.00      0.00        18
#    BRCA_LumA       0.57      0.91      0.70        88
#    BRCA_LumB       0.33      0.15      0.21        39
#
#     accuracy                           0.54       179
#    macro avg       0.36      0.35      0.33       179
# weighted avg       0.46      0.54      0.47       179
#
# MCC - Image Data: 0.2290
# AUC - Image Data: 0.6778
# Fusion Model Accuracy: 0.7039
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Report - Fusion Model:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.86      0.89      0.88        28
#    BRCA_Her2       0.88      0.39      0.54        18
#    BRCA_LumA       0.70      0.84      0.76        94
#    BRCA_LumB       0.52      0.38      0.44        39
#
#     accuracy                           0.70       179
#    macro avg       0.74      0.63      0.66       179
# weighted avg       0.70      0.70      0.69       179
#
# MCC - Fusion Model: 0.5184
# AUC - Fusion Model: 0.8555

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, matthews_corrcoef, roc_auc_score
from sklearn.preprocessing import LabelBinarizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

def utility_kernel(X, Y, p=1):
    # Custom utility kernel
    return 7*(np.dot(X, Y.T)) ** p  # Example: dot product kernel, raised to the power of p

# Function to print and plot evaluation metrics
def evaluate_model(y_true, y_pred, y_pred_proba, label_encoder, model_name="Model"):
    print(f"\n{model_name} Classification Report:")
    print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))
    
    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.title(f"{model_name} Confusion Matrix")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()
    
    # Matthews Correlation Coefficient (MCC)
    mcc = matthews_corrcoef(y_true, y_pred)
    print(f"{model_name} Matthews Correlation Coefficient (MCC): {mcc:.4f}")
    
    # Properly calculate AUC for multi-class classification
    lb = LabelBinarizer()
    lb.fit(y_true)
    y_true_binarized = lb.transform(y_true)
    
    try:
        # Calculate AUC using one-vs-rest strategy
        auc = roc_auc_score(y_true_binarized, y_pred_proba, multi_class='ovr')
        print(f"{model_name} AUC (One-vs-Rest): {auc:.4f}")
    except Exception as e:
        print(f"{model_name} AUC calculation error: {str(e)}")
    
# SVM with Custom Utility Kernel and Grid Search for Data
def train_and_evaluate_svm(X_train, y_train, X_test, y_test, label_encoder, model_name="Model", param_grid=None):
    # Default parameter grid if not provided
    if param_grid is None:
        param_grid = {
            'C': [10, 1, 0.1, 0.01, 0.001, 0.0001, 0.00001],
            'kernel': [utility_kernel],
        }
    
    # Initialize SVM with probability estimates
    svm = SVC(probability=True)
    
    # Perform Grid Search
    grid_search = GridSearchCV(svm, param_grid, cv=5, verbose=3)
    grid_search.fit(X_train, y_train)
    
    # Print best parameters
    print(f"{model_name} Best Parameters: {grid_search.best_params_}")
    
    # Best model predictions
    best_model = grid_search.best_estimator_
    pred_probs = best_model.predict_proba(X_test)
    pred = np.argmax(pred_probs, axis=1)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, pred)
    print(f"{model_name} Accuracy: {accuracy:.4f}")
    
    # Evaluate model
    evaluate_model(y_test, pred, pred_probs, label_encoder, model_name)
    
    return best_model, pred_probs

# Separate parameter grids for Gene and Image models
param_grid_gene = {
    'C': [10, 1, 0.1, 0.01, 0.001, 0.0001, 0.00001],
    'kernel': [utility_kernel],
   
}

param_grid_image = {
    'C': [0.1,0.01,0.001],
    'kernel': [utility_kernel],
    
}

# Train and evaluate Gene Model with specific parameter grid
gene_model, pred_dnn_probs = train_and_evaluate_svm(
    X_train_genes, y_train_genes_int, 
    X_test_genes, y_test_genes_int, 
    gene_label_encoder, 
    "Gene Model",
    param_grid=param_grid_gene
)

# Train and evaluate Image Model with specific parameter grid
image_model, pred_cnn_probs = train_and_evaluate_svm(
    X_train_images, y_train_images, 
    X_test_images, y_test_images, 
    image_label_encoder, 
    "Image Model",
    param_grid=param_grid_image
)

# Align prediction arrays for fusion
min_samples = min(pred_dnn_probs.shape[0], pred_cnn_probs.shape[0])
pred_dnn_aligned = pred_dnn_probs[:min_samples]
pred_cnn_aligned = pred_cnn_probs[:min_samples]
y_test_aligned = y_test_genes_int[:min_samples]

# Fusion of SVM outputs
alpha, beta = 0.88185, 0.11815
fused_predictions = alpha * pred_dnn_aligned + beta * pred_cnn_aligned
final_predictions = np.argmax(fused_predictions, axis=1)

# Evaluate fusion model
accuracy_fusion = accuracy_score(y_test_aligned, final_predictions)
print(f"Fusion Model Accuracy: {accuracy_fusion:.4f}")

# Prepare label binarizer for fusion model evaluation
lb_fusion = LabelBinarizer()
lb_fusion.fit(y_test_aligned)
y_test_binarized = lb_fusion.transform(y_test_aligned)

# Evaluate Fusion Model with proper AUC calculation
try:
    fusion_auc = roc_auc_score(y_test_binarized, fused_predictions, multi_class='ovr')
    print(f"Fusion Model AUC (One-vs-Rest): {fusion_auc:.4f}")
except Exception as e:
    print(f"Fusion Model AUC calculation error: {str(e)}")

# Evaluate Fusion Model
evaluate_model(y_test_aligned, final_predictions, fused_predictions, gene_label_encoder, "Fusion Model")
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [CV 1/5] END C=10, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.975 total time=   0.3s
# [CV 2/5] END C=10, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.969 total time=   0.2s
# [CV 3/5] END C=10, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.961 total time=   0.1s
# [CV 4/5] END C=10, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.989 total time=   0.2s
# [CV 5/5] END C=10, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.980 total time=   0.1s
# [CV 1/5] END C=1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.975 total time=   0.2s
# [CV 2/5] END C=1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.969 total time=   0.2s
# [CV 3/5] END C=1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.961 total time=   0.2s
# [CV 4/5] END C=1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.989 total time=   0.2s
# [CV 5/5] END C=1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.975 total time=   0.3s
# [CV 2/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.961 total time=   0.3s
# [CV 4/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.989 total time=   0.3s
# [CV 5/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.975 total time=   0.6s
# [CV 2/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.961 total time=   0.3s
# [CV 4/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.989 total time=   0.3s
# [CV 5/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.975 total time=   0.4s
# [CV 2/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.961 total time=   0.3s
# [CV 4/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.989 total time=   0.3s
# [CV 5/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.975 total time=   0.4s
# [CV 2/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.961 total time=   0.3s
# [CV 4/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.989 total time=   0.3s
# [CV 5/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.969 total time=   0.4s
# [CV 2/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.966 total time=   0.3s
# [CV 3/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.966 total time=   0.3s
# [CV 4/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.992 total time=   0.3s
# [CV 5/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.977 total time=   0.3s
# Gene Model Best Parameters: {'C': 10, 'kernel': <function utility_kernel at 0x000001B1682F2200>}
# Gene Model Accuracy: 0.8702
#
# Gene Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       1.00      1.00      1.00        34
#    BRCA_Her2       0.93      0.74      0.82        19
#    BRCA_LumA       0.86      0.93      0.89       109
#    BRCA_LumB       0.76      0.70      0.73        46
#
#     accuracy                           0.87       208
#    macro avg       0.89      0.84      0.86       208
# weighted avg       0.87      0.87      0.87       208
# Gene Model Matthews Correlation Coefficient (MCC): 0.7947
# Gene Model AUC (One-vs-Rest): 0.9723
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.587 total time=   6.3s
# [CV 2/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.573 total time=   4.9s
# [CV 3/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.566 total time=   5.0s
# [CV 4/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.524 total time=   4.6s
# [CV 5/5] END C=0.1, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.521 total time=   4.7s
# [CV 1/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.622 total time=   0.7s
# [CV 2/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.622 total time=   0.5s
# [CV 3/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.566 total time=   0.6s
# [CV 4/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.552 total time=   0.5s
# [CV 5/5] END C=0.01, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.535 total time=   0.5s
# [CV 1/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.636 total time=   0.0s
# [CV 2/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.650 total time=   0.0s
# [CV 3/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.573 total time=   0.0s
# [CV 4/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.601 total time=   0.0s
# [CV 5/5] END C=0.001, kernel=<function utility_kernel at 0x000001B1682F2200>;, score=0.606 total time=   0.0s
# Image Model Best Parameters: {'C': 0.001, 'kernel': <function utility_kernel at 0x000001B1682F2200>}
# Image Model Accuracy: 0.5978
#
# Image Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.62      0.62      0.62        34
#    BRCA_Her2       0.50      0.06      0.10        18
#    BRCA_LumA       0.67      0.84      0.75        88
#    BRCA_LumB       0.33      0.28      0.31        39
#
#     accuracy                           0.60       179
#    macro avg       0.53      0.45      0.44       179
# weighted avg       0.57      0.60      0.56       179
# Image Model Matthews Correlation Coefficient (MCC): 0.3603
# Image Model AUC (One-vs-Rest): 0.7621
# Fusion Model Accuracy: 0.8603
# Fusion Model AUC (One-vs-Rest): 0.9627
#
# Fusion Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       1.00      1.00      1.00        28
#    BRCA_Her2       0.93      0.72      0.81        18
#    BRCA_LumA       0.85      0.94      0.89        94
#    BRCA_LumB       0.76      0.64      0.69        39
#
#     accuracy                           0.86       179
#    macro avg       0.88      0.82      0.85       179
# weighted avg       0.86      0.86      0.86       179
# Fusion Model Matthews Correlation Coefficient (MCC): 0.7791
# Fusion Model AUC (One-vs-Rest): 0.9627

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, matthews_corrcoef, roc_auc_score
from sklearn.preprocessing import LabelBinarizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

def utility_kernel(X, Y, p=1):
    # Custom utility kernel
    return 7*(np.dot(X, Y.T)) ** p  # Example: dot product kernel, raised to the power of p

# Function to print and plot evaluation metrics
def evaluate_model(y_true, y_pred, y_pred_proba, label_encoder, model_name="Model"):
    print(f"\n{model_name} Classification Report:")
    print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))
    
    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.title(f"{model_name} Confusion Matrix")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()
    
    # Matthews Correlation Coefficient (MCC)
    mcc = matthews_corrcoef(y_true, y_pred)
    print(f"{model_name} Matthews Correlation Coefficient (MCC): {mcc:.4f}")
    
    # Properly calculate AUC for multi-class classification
    lb = LabelBinarizer()
    lb.fit(y_true)
    y_true_binarized = lb.transform(y_true)
    
    try:
        # Calculate AUC using one-vs-rest strategy
        auc = roc_auc_score(y_true_binarized, y_pred_proba, multi_class='ovr')
        print(f"{model_name} AUC (One-vs-Rest): {auc:.4f}")
    except Exception as e:
        print(f"{model_name} AUC calculation error: {str(e)}")
    
# SVM with Custom Utility Kernel and Grid Search for Data
def train_and_evaluate_svm(X_train, y_train, X_test, y_test, label_encoder, model_name="Model", param_grid=None):
    # Default parameter grid if not provided
    if param_grid is None:
        param_grid = {
            'C': [10, 1, 0.1, 0.01, 0.001, 0.0001, 0.00001],
            'kernel': [utility_kernel],
        }
    
    # Initialize SVM with probability estimates
    svm = SVC(probability=True)
    
    # Perform Grid Search
    grid_search = GridSearchCV(svm, param_grid, cv=5, verbose=3)
    grid_search.fit(X_train, y_train)

    print(f"{model_name} Best Parameters: {grid_search.best_params_}")
    
    # Print best parameters
    print(f"{model_name} Best Parameters: {grid_search.best_params_}")
    
    # Best model predictions
    best_model = grid_search.best_estimator_
    pred_probs = best_model.predict_proba(X_test)
    pred = np.argmax(pred_probs, axis=1)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, pred)
    print(f"{model_name} Accuracy: {accuracy:.4f}")
    
    # Evaluate model
    evaluate_model(y_test, pred, pred_probs, label_encoder, model_name)
    
    return best_model, pred_probs

# Separate parameter grids for Gene and Image models
param_grid_gene = {
    'C': [50,10, 1, 0.1, 0.01, 0.001, 0.0001, 0.00001],
    'kernel': [utility_kernel],
   
}

param_grid_image = {
    'C': [0.1,0.01,0.001,0.0001,0.00001,1,10,50],
    'kernel': [utility_kernel],
    
}

# Train and evaluate Gene Model with specific parameter grid
gene_model, pred_dnn_probs = train_and_evaluate_svm(
    X_train_genes, y_train_genes_int, 
    X_test_genes, y_test_genes_int, 
    gene_label_encoder, 
    "Gene Model",
    param_grid=param_grid_gene
)

# Train and evaluate Image Model with specific parameter grid
image_model, pred_cnn_probs = train_and_evaluate_svm(
    X_train_images, y_train_images, 
    X_test_images, y_test_images, 
    image_label_encoder, 
    "Image Model",
    param_grid=param_grid_image
)

# Align prediction arrays for fusion
min_samples = min(pred_dnn_probs.shape[0], pred_cnn_probs.shape[0])
pred_dnn_aligned = pred_dnn_probs[:min_samples]
pred_cnn_aligned = pred_cnn_probs[:min_samples]
y_test_aligned = y_test_genes_int[:min_samples]

# Fusion of SVM outputs
alpha, beta = 0.88185, 0.11815
fused_predictions = alpha * pred_dnn_aligned + beta * pred_cnn_aligned
final_predictions = np.argmax(fused_predictions, axis=1)

# Evaluate fusion model
accuracy_fusion = accuracy_score(y_test_aligned, final_predictions)
print(f"Fusion Model Accuracy: {accuracy_fusion:.4f}")

# Prepare label binarizer for fusion model evaluation
lb_fusion = LabelBinarizer()
lb_fusion.fit(y_test_aligned)
y_test_binarized = lb_fusion.transform(y_test_aligned)

# Evaluate Fusion Model with proper AUC calculation
try:
    fusion_auc = roc_auc_score(y_test_binarized, fused_predictions, multi_class='ovr')
    print(f"Fusion Model AUC (One-vs-Rest): {fusion_auc:.4f}")
except Exception as e:
    print(f"Fusion Model AUC calculation error: {str(e)}")

# Evaluate Fusion Model
evaluate_model(y_test_aligned, final_predictions, fused_predictions, gene_label_encoder, "Fusion Model")
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.975 total time=   0.2s
# [CV 2/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.1s
# [CV 3/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.961 total time=   0.1s
# [CV 4/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.989 total time=   0.1s
# [CV 5/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.980 total time=   0.1s
# [CV 1/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.975 total time=   0.2s
# [CV 2/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.2s
# [CV 3/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.961 total time=   0.1s
# [CV 4/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.989 total time=   0.1s
# [CV 5/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.980 total time=   0.1s
# [CV 1/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.975 total time=   0.2s
# [CV 2/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.2s
# [CV 3/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.961 total time=   0.1s
# [CV 4/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.989 total time=   0.2s
# [CV 5/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.975 total time=   0.4s
# [CV 2/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.961 total time=   0.4s
# [CV 4/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.989 total time=   0.4s
# [CV 5/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.975 total time=   0.4s
# [CV 2/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.961 total time=   0.3s
# [CV 4/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.989 total time=   0.3s
# [CV 5/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.975 total time=   0.4s
# [CV 2/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.961 total time=   0.3s
# [CV 4/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.989 total time=   0.3s
# [CV 5/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.975 total time=   0.4s
# [CV 2/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.3s
# [CV 3/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.961 total time=   0.3s
# [CV 4/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.989 total time=   0.3s
# [CV 5/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.980 total time=   0.3s
# [CV 1/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.969 total time=   0.4s
# [CV 2/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.966 total time=   0.3s
# [CV 3/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.966 total time=   0.3s
# [CV 4/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.992 total time=   0.3s
# [CV 5/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.977 total time=   0.3s
# Gene Model Best Parameters: {'C': 50, 'kernel': <function utility_kernel at 0x000001B15611B6A0>}
# Gene Model Best Parameters: {'C': 50, 'kernel': <function utility_kernel at 0x000001B15611B6A0>}
# Gene Model Accuracy: 0.8654
#
# Gene Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       1.00      1.00      1.00        34
#    BRCA_Her2       0.93      0.74      0.82        19
#    BRCA_LumA       0.86      0.93      0.89       109
#    BRCA_LumB       0.76      0.67      0.71        46
#
#     accuracy                           0.87       208
#    macro avg       0.89      0.83      0.86       208
# weighted avg       0.86      0.87      0.86       208
# Gene Model Matthews Correlation Coefficient (MCC): 0.7870
# Gene Model AUC (One-vs-Rest): 0.9730
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.587 total time=   5.8s
# [CV 2/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.573 total time=   4.9s
# [CV 3/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.566 total time=   5.3s
# [CV 4/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.524 total time=   5.8s
# [CV 5/5] END C=0.1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.521 total time=   7.1s
# [CV 1/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.622 total time=   0.5s
# [CV 2/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.622 total time=   0.6s
# [CV 3/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.566 total time=   0.6s
# [CV 4/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.552 total time=   0.6s
# [CV 5/5] END C=0.01, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.535 total time=   0.5s
# [CV 1/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.636 total time=   0.0s
# [CV 2/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.650 total time=   0.0s
# [CV 3/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.573 total time=   0.0s
# [CV 4/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.601 total time=   0.0s
# [CV 5/5] END C=0.001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.606 total time=   0.0s
# [CV 1/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.608 total time=   0.0s
# [CV 2/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.580 total time=   0.0s
# [CV 3/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.545 total time=   0.0s
# [CV 4/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.552 total time=   0.0s
# [CV 5/5] END C=0.0001, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.563 total time=   0.0s
# [CV 1/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.469 total time=   0.0s
# [CV 2/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.469 total time=   0.0s
# [CV 3/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.469 total time=   0.0s
# [CV 4/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.469 total time=   0.0s
# [CV 5/5] END C=1e-05, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.472 total time=   0.0s
# [CV 1/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.580 total time=  57.6s
# [CV 2/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.552 total time=  49.4s
# [CV 3/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.531 total time=  47.2s
# [CV 4/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.510 total time=  48.5s
# [CV 5/5] END C=1, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.535 total time=  38.7s
# [CV 1/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.580 total time= 4.8min
# [CV 2/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.559 total time= 8.0min
# [CV 3/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.517 total time=10.9min
# [CV 4/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.538 total time= 8.8min
# [CV 5/5] END C=10, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.514 total time= 4.1min
# [CV 1/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.601 total time=31.4min
# [CV 2/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.580 total time=22.2min
# [CV 3/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.510 total time=23.1min
# [CV 4/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.531 total time=20.7min
# [CV 5/5] END C=50, kernel=<function utility_kernel at 0x000001B15611B6A0>;, score=0.507 total time=26.1min
# Image Model Best Parameters: {'C': 0.001, 'kernel': <function utility_kernel at 0x000001B15611B6A0>}
# Image Model Best Parameters: {'C': 0.001, 'kernel': <function utility_kernel at 0x000001B15611B6A0>}
# Image Model Accuracy: 0.5978
#
# Image Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       0.62      0.62      0.62        34
#    BRCA_Her2       0.00      0.00      0.00        18
#    BRCA_LumA       0.70      0.83      0.76        88
#    BRCA_LumB       0.32      0.33      0.33        39
#
#     accuracy                           0.60       179
#    macro avg       0.41      0.45      0.43       179
# weighted avg       0.53      0.60      0.56       179
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vinay\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Image Model Matthews Correlation Coefficient (MCC): 0.3662
# Image Model AUC (One-vs-Rest): 0.7617
# Fusion Model Accuracy: 0.8659
# Fusion Model AUC (One-vs-Rest): 0.9637
#
# Fusion Model Classification Report:
#               precision    recall  f1-score   support
#
#   BRCA_Basal       1.00      1.00      1.00        28
#    BRCA_Her2       0.93      0.72      0.81        18
#    BRCA_LumA       0.85      0.95      0.89        94
#    BRCA_LumB       0.78      0.64      0.70        39
#
#     accuracy                           0.87       179
#    macro avg       0.89      0.83      0.85       179
# weighted avg       0.87      0.87      0.86       179
# Fusion Model Matthews Correlation Coefficient (MCC): 0.7883
# Fusion Model AUC (One-vs-Rest): 0.9637
